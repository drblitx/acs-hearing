# %%
import pandas as pd

# %%
df = pd.read_csv('../data/county_2023/raw/ACSDT5Y2023.B18102-Data.csv', index_col=False)

# %%
# remove the last unnamed NA column
df = df.loc[:, ~df.columns.str.match("^Unnamed")]

# %%
df.head()
# Out:
#         Geography     Geographic Area Name  Estimate!!Total:  \
# 0  0500000US01001  Autauga County, Alabama             57953
# 1  0500000US01003  Baldwin County, Alabama            236704
# 2  0500000US01005  Barbour County, Alabama             21685
# 3  0500000US01007     Bibb County, Alabama             20781
# 4  0500000US01009   Blount County, Alabama             58829
#
#    Margin of Error!!Total:  Estimate!!Total:!!Male:  \
# 0                      269                    27680
# 1                      281                   114676
# 2                       96                     9960
# 3                      273                    10637
# 4                       18                    29702
#
#    Margin of Error!!Total:!!Male:  Estimate!!Total:!!Male:!!Under 5 years:  \
# 0                             344                                     1720
# 1                             393                                     6456
# 2                             159                                      614
# 3                             305                                      535
# 4                             178                                     1749
#
#    Margin of Error!!Total:!!Male:!!Under 5 years:  \
# 0                                             223
# 1                                              97
# 2                                              54
# 3                                             113
# 4                                              55
#
#    Estimate!!Total:!!Male:!!Under 5 years:!!With a hearing difficulty  \
# 0                                                  0
# 1                                                 12
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Margin of Error!!Total:!!Male:!!Under 5 years:!!With a hearing difficulty  \
# 0                                                 31
# 1                                                 28
# 2                                                 25
# 3                                                 25
# 4                                                 31
#
#    ...  Estimate!!Total:!!Female:!!65 to 74 years:!!With a hearing difficulty  \
# 0  ...                                                149
# 1  ...                                                843
# 2  ...                                                132
# 3  ...                                                 59
# 4  ...                                                234
#
#    Margin of Error!!Total:!!Female:!!65 to 74 years:!!With a hearing difficulty  \
# 0                                                 87
# 1                                                319
# 2                                                 78
# 3                                                 95
# 4                                                 98
#
#    Estimate!!Total:!!Female:!!65 to 74 years:!!No hearing difficulty  \
# 0                                               2772
# 1                                              15411
# 2                                               1415
# 3                                               1073
# 4                                               3233
#
#    Margin of Error!!Total:!!Female:!!65 to 74 years:!!No hearing difficulty  \
# 0                                                 90
# 1                                                338
# 2                                                 78
# 3                                                117
# 4                                                180
#
#    Estimate!!Total:!!Female:!!75 years and over:  \
# 0                                           2322
# 1                                          10808
# 2                                           1149
# 3                                            857
# 4                                           2420
#
#    Margin of Error!!Total:!!Female:!!75 years and over:  \
# 0                                                 85
# 1                                                178
# 2                                                 52
# 3                                                 81
# 4                                                 52
#
#    Estimate!!Total:!!Female:!!75 years and over:!!With a hearing difficulty  \
# 0                                                408
# 1                                               1256
# 2                                                137
# 3                                                184
# 4                                                667
#
#    Margin of Error!!Total:!!Female:!!75 years and over:!!With a hearing difficulty  \
# 0                                                133
# 1                                                269
# 2                                                 73
# 3                                                 83
# 4                                                220
#
#    Estimate!!Total:!!Female:!!75 years and over:!!No hearing difficulty  \
# 0                                               1914
# 1                                               9552
# 2                                               1012
# 3                                                673
# 4                                               1753
#
#    Margin of Error!!Total:!!Female:!!75 years and over:!!No hearing difficulty
# 0                                                159
# 1                                                337
# 2                                                 88
# 3                                                115
# 4                                                230
#
# [5 rows x 80 columns]

# %%
df.columns
# Out:
# Index(['Geography', 'Geographic Area Name', 'Estimate!!Total:',
#        'Margin of Error!!Total:', 'Estimate!!Total:!!Male:',
#        'Margin of Error!!Total:!!Male:',
#        'Estimate!!Total:!!Male:!!Under 5 years:',
#        'Margin of Error!!Total:!!Male:!!Under 5 years:',
#        'Estimate!!Total:!!Male:!!Under 5 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!Under 5 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Male:!!Under 5 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!Under 5 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Male:!!5 to 17 years:',
#        'Margin of Error!!Total:!!Male:!!5 to 17 years:',
#        'Estimate!!Total:!!Male:!!5 to 17 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!5 to 17 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Male:!!5 to 17 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!5 to 17 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Male:!!18 to 34 years:',
#        'Margin of Error!!Total:!!Male:!!18 to 34 years:',
#        'Estimate!!Total:!!Male:!!18 to 34 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!18 to 34 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Male:!!18 to 34 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!18 to 34 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Male:!!35 to 64 years:',
#        'Margin of Error!!Total:!!Male:!!35 to 64 years:',
#        'Estimate!!Total:!!Male:!!35 to 64 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!35 to 64 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Male:!!35 to 64 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!35 to 64 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Male:!!65 to 74 years:',
#        'Margin of Error!!Total:!!Male:!!65 to 74 years:',
#        'Estimate!!Total:!!Male:!!65 to 74 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!65 to 74 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Male:!!65 to 74 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!65 to 74 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Male:!!75 years and over:',
#        'Margin of Error!!Total:!!Male:!!75 years and over:',
#        'Estimate!!Total:!!Male:!!75 years and over:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!75 years and over:!!With a hearing difficulty',
#        'Estimate!!Total:!!Male:!!75 years and over:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Male:!!75 years and over:!!No hearing difficulty',
#        'Estimate!!Total:!!Female:', 'Margin of Error!!Total:!!Female:',
#        'Estimate!!Total:!!Female:!!Under 5 years:',
#        'Margin of Error!!Total:!!Female:!!Under 5 years:',
#        'Estimate!!Total:!!Female:!!Under 5 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!Under 5 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Female:!!Under 5 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!Under 5 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Female:!!5 to 17 years:',
#        'Margin of Error!!Total:!!Female:!!5 to 17 years:',
#        'Estimate!!Total:!!Female:!!5 to 17 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!5 to 17 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Female:!!5 to 17 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!5 to 17 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Female:!!18 to 34 years:',
#        'Margin of Error!!Total:!!Female:!!18 to 34 years:',
#        'Estimate!!Total:!!Female:!!18 to 34 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!18 to 34 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Female:!!18 to 34 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!18 to 34 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Female:!!35 to 64 years:',
#        'Margin of Error!!Total:!!Female:!!35 to 64 years:',
#        'Estimate!!Total:!!Female:!!35 to 64 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!35 to 64 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Female:!!35 to 64 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!35 to 64 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Female:!!65 to 74 years:',
#        'Margin of Error!!Total:!!Female:!!65 to 74 years:',
#        'Estimate!!Total:!!Female:!!65 to 74 years:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!65 to 74 years:!!With a hearing difficulty',
#        'Estimate!!Total:!!Female:!!65 to 74 years:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!65 to 74 years:!!No hearing difficulty',
#        'Estimate!!Total:!!Female:!!75 years and over:',
#        'Margin of Error!!Total:!!Female:!!75 years and over:',
#        'Estimate!!Total:!!Female:!!75 years and over:!!With a hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!75 years and over:!!With a hearing difficulty',
#        'Estimate!!Total:!!Female:!!75 years and over:!!No hearing difficulty',
#        'Margin of Error!!Total:!!Female:!!75 years and over:!!No hearing difficulty'],
#       dtype='object')

# %%
def clean_col(name):
    if name.startswith("Estimate!!"):
        name = name.replace("Estimate!!", "")
    elif name.startswith("Margin of Error!!"):
        name = name.replace("Margin of Error!!", "moe_")
    
    name = name.replace("Estimate!!", "").replace("Margin of Error!!", "")
    name = name.replace("Estimate!!Total:", "total")
    name = name.replace("Male:", "male")
    name = name.replace("Female:", "female")
    name = name.replace("Under 5 years:", "under5")
    name = name.replace("5 to 17 years:", "5to17")
    name = name.replace("18 to 34 years:", "18to34")
    name = name.replace("35 to 64 years:", "35to64")
    name = name.replace("65 to 74 years:", "65to74")
    name = name.replace("75 years and over:", "75plus")
    name = name.replace("With a hearing difficulty", "hearing_diff")
    name = name.replace("No hearing difficulty", "no_hearing_diff")

    name = name.replace("!!", "_").replace(":", "").replace(" ", "_").lower()
    
    return name

df.columns = [clean_col(c) for c in df.columns]

# %%
df.head()
# Out:
#         geography     geographic_area_name   total  moe_total  total_male  \
# 0  0500000US01001  Autauga County, Alabama   57953        269       27680
# 1  0500000US01003  Baldwin County, Alabama  236704        281      114676
# 2  0500000US01005  Barbour County, Alabama   21685         96        9960
# 3  0500000US01007     Bibb County, Alabama   20781        273       10637
# 4  0500000US01009   Blount County, Alabama   58829         18       29702
#
#    moe_total_male  total_male_under5  moe_total_male_under5  \
# 0             344               1720                    223
# 1             393               6456                     97
# 2             159                614                     54
# 3             305                535                    113
# 4             178               1749                     55
#
#    total_male_under5_hearing_diff  moe_total_male_under5_hearing_diff  ...  \
# 0                               0                                  31  ...
# 1                              12                                  28  ...
# 2                               0                                  25  ...
# 3                               0                                  25  ...
# 4                               0                                  31  ...
#
#    total_female_65to74_hearing_diff  moe_total_female_65to74_hearing_diff  \
# 0                               149                                    87
# 1                               843                                   319
# 2                               132                                    78
# 3                                59                                    95
# 4                               234                                    98
#
#    total_female_65to74_no_hearing_diff  \
# 0                                 2772
# 1                                15411
# 2                                 1415
# 3                                 1073
# 4                                 3233
#
#    moe_total_female_65to74_no_hearing_diff  total_female_75plus  \
# 0                                       90                 2322
# 1                                      338                10808
# 2                                       78                 1149
# 3                                      117                  857
# 4                                      180                 2420
#
#    moe_total_female_75plus  total_female_75plus_hearing_diff  \
# 0                       85                               408
# 1                      178                              1256
# 2                       52                               137
# 3                       81                               184
# 4                       52                               667
#
#    moe_total_female_75plus_hearing_diff  total_female_75plus_no_hearing_diff  \
# 0                                   133                                 1914
# 1                                   269                                 9552
# 2                                    73                                 1012
# 3                                    83                                  673
# 4                                   220                                 1753
#
#    moe_total_female_75plus_no_hearing_diff
# 0                                      159
# 1                                      337
# 2                                       88
# 3                                      115
# 4                                      230
#
# [5 rows x 80 columns]

# %%
# export df to a clean csv
df.to_csv("../data/county_2023/clean/acs_county2023.csv", index=False, na_rep="")
